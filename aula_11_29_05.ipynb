# %% [markdown]
# <a href="https://colab.research.google.com/github/isamlibarino/aula-P.A/blob/main/aula_11_29_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

a = random.random()
print (a)
# Out:
# 0.6452679111335299

# %%
import random

a = random.randint(1,100)
print (a)
# Out:
# 48

# %%
# Escrever um jogo de adivinhação. O usuário terá 03 chances para adivinhar o número de 0 a 10.
# o programa dar uma mensagem se o palpite for maior ou menor
# o programa avisar quente ou frio

import random
numero = random.randint(0,10)
tentativas= 0
max_tentativas = 3
print("Bem-vindo ao jogo de adivinhação!")
print(f"Adivinhe o número. Você tem {3} chances.")


while tentativas < max_tentativas:
  try:
    palpite = int(input("Digite seu palpite: "))
    tentativas += 1


  if tentativas == numero:
   print(f"Parabéns! Você adivinhou o número {numero} em {tentativas} tentativas!")
   return


  elif tentativas < numero:
   print("Seu palpite é muito baixo.")
else:
   print("Seu palpite é muito alto.")
# Out:
#   File "/tmp/ipykernel_1611/4207530783.py", line 19
#     if tentativas == numero:
#     ^
# SyntaxError: expected 'except' or 'finally' block
