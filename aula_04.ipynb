# %% [markdown]
# <a href="https://colab.research.google.com/github/isamlibarino/aula-P.A/blob/main/aula_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de P.A
#
# * Calcular uma área
#
# # Entrada
#
# Ler lado 1
#
# Ler lado2
#
# # Processamento
#
# área = lado1 * lado2
#
# #Saída
#
# escrever o total da área

# %%
# Variáveis que recebe o valor dos lados

# Entrada
lado1 = 7
lado2 = 3

# %%
# Processamento

área = lado1 * lado2

# %%
# Saída

print (f"total da área calculada: {área} metros quadrados")
# Out:
# total da área calculada: 21 metros quadrados

# %% [markdown]
#   Operadores aritméticos:
#
#
#
# 1.   Soma = +
# 2.   Subtração = -
# 3.   Multiplicação = *
# 4.   Divisão = /

# %% [markdown]
# Atividade:
#
# Fazer um algorítmo e depois um programa que recebe 4 notas do aluno e calcula a média aritmética e imprime a média.

# %%
# Variável que recebe as notas do aluno

# Entrada
Nota1 = 6
Nota2 = 8
Nota3 = 5
Nota4 = 10

# %%
# Processamento

Nota = Nota1 + Nota2 + Nota3 + Nota4
Média = Nota/4

# %%
# Saída
print (f"Valor do resultado da sua nota bimestral: {Média} Nota final")
# Out:
# Valor do resultado da sua nota bimestral: 21.5 Nota final

# %% [markdown]
# Atividade: faça um algorítmo que receba um número e calcule o dobro desse número

# %%
# Variável que recebe um número

# Entrada
número = 5

# %%
# Processamento
total = número * 2

# %%
# Saída
print (f"Resultado final : {total}")
# Out:
# Resultado final : 10
