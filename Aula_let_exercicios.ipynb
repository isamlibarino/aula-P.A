# %% [markdown]
# <a href="https://colab.research.google.com/github/isamlibarino/aula-P.A/blob/main/Aula_let_exercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercício 1

# %%
nome = input("Digite seu nome: ")
idade = input("Digite sua idade: ")
cidade = input("Digite sua cidade: ")

print(f"Meu nome é {nome}, tenho {idade} anos e moro em {cidade}.")
# Out:
# Digite seu nome: Isabela
# Digite sua idade: 15
# Digite sua cidade: Ribeirão Pires
# Meu nome é Isabela, tenho 15 anos e moro em Ribeirão Pires.

# %% [markdown]
# Exercício 2

# %%
numero = int(input("Digite um número inteiro: "))
antecessor = numero - 1
sucessor = numero + 1

print(f"O numero é : {numero}")
print(f"O antecessor é : {antecessor}")
print(f"O sucessor é : {sucessor}")
# Out:
# Digite um número inteiro:  9
# O numero é : 9
# O antecessor é : 8
# O sucessor é : 10

# %% [markdown]
# Exercício 3

# %%
try:
    numero1 = float(input("Digite o primeiro número: "))
    numero2 = float(input("Digite o segundo número: "))

    soma = numero1 + numero2
    subtracao = numero1 - numero2
    multiplicacao = numero1 * numero2

    print(f"Soma: {soma}")
    print(f"Subtração: {subtracao}")
    print(f"Multiplicação: {multiplicacao}")

    if numero2 != 0:
        divisao = numero1 / numero2
        print(f"Divisão: {divisao}")
    else:
        print("não é possível dividir por zero.")
except ValueError:
    print("Por favor, digite números válidos")
# Out:
# Digite o primeiro número:  6
# Digite o segundo número:  3
# Soma: 9.0
# Subtração: 3.0
# Multiplicação: 18.0
# Divisão: 2.0

# %% [markdown]
# Exercício 4

# %%
try:
    nota1 = float(input("Digite a primeira nota: "))
    nota2 = float(input("Digite a segunda nota: "))
    nota3 = float(input("Digite a terceira nota: "))

    media = (nota1 + nota2 + nota3) / 3

    print(f"Média do aluno: {media:.2f}")

    if media >= 7:
        print("Você está aprovado")
    elif 5 <= media < 7:
        print("Você está de recuperação")
    else:
        print("Você está reprovado")

except ValueError:
    print("Erro, digite números para as notas.")
# Out:
# Digite a primeira nota:  7
# Digite a segunda nota:  6
# Digite a terceira nota:  10
# Média do aluno: 7.67
# Você está aprovado

# %% [markdown]
# Exercícios 5

# %%
celsius = float(input("Digite a temperatura em celsius:"))

fahrenheit = (celsius * 9/5) + 32

print (f"{celsius}°C é igual a {fahrenheit}°F")
# Out:
# Digite a temperatura em celsius:27
# 27.0°C é igual a 80.6°F

# %% [markdown]
# Exercício 6

# %%
comprimento = float (input("Digite o valor do comprimento:"))
altura = float (input("Digite o valor da altura:"))

area = comprimento * altura

print (f"A área do retângulo e igual : {area}")
# Out:
# Digite o valor do comprimento: 30
# Digite o valor da altura:15
# A área do retângulo e igual : 450.0

# %% [markdown]
# Exercício 7

# %%
numero = int (input("digite um número: "))

if numero % 2 == 0:

  print (f" O número {numero} é par.")

else:
  print (f"O numero {numero} é ímpar")
# Out:
# digite um número:  6
#  O número 6 é par.

# %% [markdown]
# Exercício 8

# %%
n1 = float(input("Digite o primeiro número: "))
n2 = float(input("Digite o segundo número: "))
n3 = float(input("Digite o terceiro número: "))

if n1 > n2 and n1 > n3:
    maior = n1
elif n2 > n1 and n2 > n3:
    maior = n2
else:
    maior = n3

print("O maior número é:", maior)
# Out:
# Digite o primeiro número:  9
# Digite o segundo número:  8
# Digite o terceiro número: 11
# O maior número é: 11.0

# %% [markdown]
# Exercíco 9

# %%
numero = int(input("Digite um numero"))

for i in range(11):
  print(f"{numero} x {i} = {numero * i}")
# Out:
# Digite um numero 14
# 14 x 0 = 0
# 14 x 1 = 14
# 14 x 2 = 28
# 14 x 3 = 42
# 14 x 4 = 56
# 14 x 5 = 70
# 14 x 6 = 84
# 14 x 7 = 98
# 14 x 8 = 112
# 14 x 9 = 126
# 14 x 10 = 140

# %% [markdown]
# Exercício 10

# %%
numero1 = int (input("digite um numero: "))
numero2 = int (input("digite um numero: "))

soma = numero1 + numero2

print (f"A soma é {soma}")
# Out:
# digite um numero:  4
# digite um numero: 7
# A soma é 11
