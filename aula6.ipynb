# %% [markdown]
# <a href="https://colab.research.google.com/github/isamlibarino/aula-P.A/blob/main/aula6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *Exercícios com operadores aritméticos

# %% [markdown]
# *SOMA

# %%
# Entrada

numero1 = 2
numero2 = 9

# %%
# Processamento

soma = numero1 + numero2

# %%
# Saída

print (f"resultado final : {soma}")
# Out:
# resultado final : 18

# %% [markdown]
# *SUBTRAÇÃO

# %%
# Entrada

numero1 = 25
numero2 = 15

# %%
# Processamento

subtração = numero1 - numero2

# %%
# Saída

print (f"resultado final : {subtração}")
# Out:
# resultado final : 10

# %% [markdown]
# *MULTIPLICAÇÃO

# %%
# Entrada

numero1 = 6
numero2 = 7

# %%
# Processmento

multiplicação = numero1 * numero2

# %%
# Saída

print(f"resultado da final : {multiplicação}")
# Out:
# resultado da final : 42
