# %% [markdown]
# <a href="https://colab.research.google.com/github/isamlibarino/aula-P.A/blob/main/Aula_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de programação e algorítmos
#
# *Introdução a programação

# %%
print("olá mundo")
# Out:
# olá mundo

# %% [markdown]
# # Tipo Texto

# %%
nome = "Isabela" # str

# %% [markdown]
# # Tipos Numéricos

# %%
idade = 14 # int

# %%
altura = 1.59 # float

# %%
numero_complexo = 2 + 3j # complex

# %% [markdown]
# # Tipo Booleano

# %%
esta_chovendo = False # bool

# %% [markdown]
# # Tipo Lista (mutável)

# %%
numeros = [1, 2, 3, 4, 5] # list

# %% [markdown]
# # Tipo Tupla (mutável)

# %%
coordenadas = (10, 20) # tuple

# %% [markdown]
# # Tipo Conjunto (valores únicos)

# %%
vogais = { 'a', 'e', 'i', 'o', 'u'} # set

# %% [markdown]
# # Tipo dicionário (chave-valor)

# %%
pessoa = {"nome": "Carlos", "idade": 30} # dict

# %%
print (f"Nome: {nome}, Idade: {idade}, Altura: {altura}")
# Out:
# Nome: Isabela, Idade: 14, Altura: 1.59
