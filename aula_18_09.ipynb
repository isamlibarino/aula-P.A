# %% [markdown]
# <a href="https://colab.research.google.com/github/isamlibarino/aula-P.A/blob/main/aula_18_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LISTAS

# %% [markdown]
# Ex 1

# %%
frutas = ['maçã', 'banana', 'laranja', 'morango']
print(frutas)
# Out:
# ['maçã', 'banana', 'laranja', 'morango']

# %% [markdown]
# Ex 2

# %%
nomes = ["Rebeca", "Guilherme", "Melissa", "Kyara"]
print(nomes[0])
print(nomes[1])
print(nomes[3])
# Out:
# Rebeca
# Guilherme
# Kyara

# %% [markdown]
# Ex 3

# %%
cores = ["vermelho", "azul", "verde"]
cores[1] = "amarelo"
print(cores)
# Out:
# ['vermelho', 'amarelo', 'verde']

# %% [markdown]
# Ex 4

# %%
alunos = ["Nicolas", "Wendel", "Pyetra"]
alunos.append("Petros")
print(alunos)
# Out:
# ['Nicolas', 'Wendel', 'Pyetra', 'Petros']

# %% [markdown]
# Ex 5

# %%
animais = ["cachorro", "gato", "coelho", "passarinho"]
animais.remove("coelho")
print(animais)
# Out:
# ['cachorro', 'gato', 'passarinho']

# %% [markdown]
# TUPLAS

# %% [markdown]
# Ex 1

# %%
meses = ("Janeiro", "Fevereiro", "Março", "Abril")
print(meses)
# Out:
# ('Janeiro', 'Fevereiro', 'Março', 'Abril')

# %% [markdown]
# Ex 2

# %%
numeros = (10, 20, 30, 40, 50)
print(numeros[0])
print(numeros[2])
print(numeros[4])
# Out:
# 10
# 30
# 50

# %% [markdown]
# Ex 3

# %%
aluna = ("Isabela", 15, "Informática para Internet")
print(aluna[0])
print(aluna[1])
print(aluna[2])
# Out:
# Isabela
# 15
# Informática para Internet

# %% [markdown]
# Ex 4

# %%
cores = ("vermelho", "azul", "verde")
cores.append("amarelo")
print(cores)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1588/1752615755.py in <cell line: 0>()
#       1 cores = ("vermelho", "azul", "verde")
# ----> 2 cores.append("amarelo")
#       3 print(cores)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# Ex 5

# %%
numeros = (2, 4, 6, 8, 10)
numeros.count(2)
# Out:
# 1
